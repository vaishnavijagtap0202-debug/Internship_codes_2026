# %% [markdown]
# # Weekly Assignment 2

# %%
"""
Write a function analyze_sentence(sentence) that takes a sentence and returns a dictionary with
word_count, char_count (excluding spaces), unique_words (case-insensitive), and
most_frequent_word.

Test it with:
"The quick brown fox jumps over the lazy dog the fox"
"""

# %%
def analyze_sentence(sentence):

    words = sentence.lower().split()

    word_count = len(words)

    char_count = len(sentence.replace(" ", ""))

    unique_words = len(set(words))

    max_count = 0
    most_frequent_word = ""

    for word in words:
        count = words.count(word)

        if count > max_count:
            max_count = count
            most_frequent_word = word

    return {
        "word_count": word_count,
        "char_count": char_count,
        "unique_words": unique_words,
        "most_frequent_word": most_frequent_word
    }

# %%
"""
Given the string below, do the following and print each result:

text = "A man a plan a canal Panama"

a) Reverse the string without using slicing.
b) Check if it is a palindrome, ignoring case and spaces.
c) Replace every vowel with *.
d) Count how many times each vowel appears.
"""

# %%
text = "A man a plan a canal Panama"

# a) Reverse the string
reverse = ""

for ch in text:
    reverse = ch + reverse

print("Reversed String:", reverse)

# b) Palindrome check
new_text = text.lower().replace(" ", "")

if new_text == new_text[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")

# c) Replace vowels with *
new_string = ""

for ch in text:
    if ch.lower() in "aeiou":
        new_string += "*"
    else:
        new_string += ch

print("After Replacing Vowels:", new_string)

# d) Count vowels
a = e = i = o = u = 0

for ch in text.lower():
    if ch == 'a':
        a += 1
    elif ch == 'e':
        e += 1
    elif ch == 'i':
        i += 1
    elif ch == 'o':
        o += 1
    elif ch == 'u':
        u += 1

print("a =", a)
print("e =", e)
print("i =", i)
print("o =", o)
print("u =", u)
# Out:
# Reversed String: amanaP lanac a nalp a nam A
# Palindrome
# After Replacing Vowels: * m*n * pl*n * c*n*l P*n*m*
# a = 10
# e = 0
# i = 0
# o = 0
# u = 0

# %%
"""
Write a function format_report(data) that takes a list of tuples
(name, score, grade) and prints a formatted table where

name is left-aligned (width 15),
score is right-aligned (width 6),
and grade is centered (width 8).

Use this data:
data = [("Alice", 92, "A"),("Bob", 78, "B+"),("Charlie", 55, "C"),("Diana", 100, "A+")]
"""

# %%
def format_report(data):

    print("Name    Score   Grade")

    for name, score, grade in data:
        print(f"{name:<15}{score:>6}{grade:^8}")

data = [ ("Alice", 92, "A"),("Bob", 78, "B+"),("Charlie", 55, "C"),("Diana", 100, "A+")]

format_report(data)
# Out:
# Name    Score   Grade
# Alice              92   A
# Bob                78   B+
# Charlie            55   C
# Diana             100   A+

# %%
"""
Write a function list_ops(nums) that:

a) Removes duplicates while preserving the original order.

b) Returns a new list with only elements at even indices, squared.

c) Flattens the nested list into a single list using list comprehension.

nums = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]

nested = [[1, 2, 3], [4, 5], [6, 7, 8, 9]]
"""

# %%
def list_ops(nums):

    # a) Remove duplicates
    unique = []

    for i in nums:
        if i not in unique:
            unique.append(i)

    print("Without Duplicates:", unique)

    # b) Even index elements squared
    square_list = []

    for i in range(0, len(nums), 2):
        square_list.append(nums[i] ** 2)

    print("Even Index Squared:", square_list)

    # c) Flatten nested list
    nested = [[1, 2, 3], [4, 5], [6, 7, 8, 9]]

    flat = [item for sublist in nested for item in sublist]

    print("Flattened List:", flat)


nums = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]

list_ops(nums)
# Out:
# Without Duplicates: [3, 1, 4, 5, 9, 2, 6]
# Even Index Squared: [9, 16, 25, 4, 25, 25]
# Flattened List: [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
"""
Given the tuple below:

employee = ("E042", "Riya Sharma", "Data Science", 72000, "Pune")

a) Unpack it into meaningful variable names.

b) Use * unpacking to separate the first element, the last, and everything in between.

c) Write a function update_salary(emp_tuple, new_salary)
that returns a new tuple with the salary updated.
"""

# %%
employee = ("E042", "Riya Sharma", "Data Science", 72000, "Pune")

# a) Unpacking

emp_id, name, department, salary, city = employee

print(emp_id)
print(name)
print(department)
print(salary)
print(city)

# b) * unpacking

first, *middle, last = employee

print("First =", first)
print("Middle =", middle)
print("Last =", last)

# c) Update salary

def update_salary(emp_tuple, new_salary):

    return (
        emp_tuple[0],
        emp_tuple[1],
        emp_tuple[2],
        new_salary,
        emp_tuple[4]
    )

new_employee = update_salary(employee, 80000)

print(new_employee)
# Out:
# E042
# Riya Sharma
# Data Science
# 72000
# Pune
# First = E042
# Middle = ['Riya Sharma', 'Data Science', 72000]
# Last = Pune
# ('E042', 'Riya Sharma', 'Data Science', 80000, 'Pune')

# %%
"""
Using the sets below, find:

batch_a = {"Aarav", "Priya", "Karan", "Meera", "Sahil"}

batch_b = {"Karan", "Meera", "Tanvi", "Rohan"}

batch_c = {"Priya", "Aarav"}

a) Students present in both batches.

b) Students in batch_a but not in batch_b.

c) All unique students across both batches.

d) Whether batch_c is a subset of batch_a.
"""

# %%
batch_a = {"Aarav", "Priya", "Karan", "Meera", "Sahil"}

batch_b = {"Karan", "Meera", "Tanvi", "Rohan"}

batch_c = {"Priya", "Aarav"}

# a)

print("Common Students:")
print(batch_a & batch_b)

# b)

print("Only in batch_a:")
print(batch_a - batch_b)

# c)

print("All Unique Students:")
print(batch_a | batch_b)

# d)

print("Is batch_c subset of batch_a?")
print(batch_c.issubset(batch_a))
# Out:
# Common Students:
# {'Meera', 'Karan'}
# Only in batch_a:
# {'Priya', 'Aarav', 'Sahil'}
# All Unique Students:
# {'Meera', 'Karan', 'Priya', 'Tanvi', 'Sahil', 'Rohan', 'Aarav'}
# Is batch_c subset of batch_a?
# True

# %%
"""
Write a function inventory_manager(records) that takes a list of tuples
(product, category, quantity, price) and returns a dictionary grouped by category.

Each category should have:
1. total_items
2. total_value
3. list of product names
"""

# %%
def inventory_manager(records):

    inventory = {}

    for product, category, quantity, price in records:

        if category not in inventory:

            inventory[category] = {
                "total_items": 0,
                "total_value": 0,
                "products": []
            }

        inventory[category]["total_items"] += quantity
        inventory[category]["total_value"] += quantity * price
        inventory[category]["products"].append(product)

    return inventory


records = [
    ("Laptop", "Electronics", 10, 55000),
    ("Mouse", "Electronics", 50, 499),
    ("Desk", "Furniture", 8, 12000),
    ("Chair", "Furniture", 15, 4500),
    ("Pen", "Stationery", 200, 20)
]

print(inventory_manager(records))
# Out:
# {'Electronics': {'total_items': 60, 'total_value': 574950, 'products': ['Laptop', 'Mouse']}, 'Furniture': {'total_items': 23, 'total_value': 163500, 'products': ['Desk', 'Chair']}, 'Stationery': {'total_items': 200, 'total_value': 4000, 'products': ['Pen']}}

# %%
"""
A function power_all(*args, exp=2) that returns
a list of each number raised to exp.
"""

# %%
def power_all(*args, exp=2):

    result = []

    for i in args:
        result.append(i ** exp)

    return result
# Out:
# [4, 9, 16]

# %%
power_all(4,5,6)
# Out:
# [16, 25, 36]

# %%
"""
A function profile(**kwargs) that prints each key-value pair as Key : Value.
"""

# %%
def profile(**kwargs):

    for key, value in kwargs.items():
        print(key, ":", value)

# %%
profile(name="Vaishnavi", age=18, city="Mumbai")
# Out:
# name : Vaishnavi
# age : 18
# city : Mumbai

# %%
"""
Use a lambda inside sorted() to sort the list
of dicts below by cgpa in descending order.
"""

# %%
students = [
    {"name": "Arjun", "cgpa": 8.4},
    {"name": "Sanya", "cgpa": 9.1},
    {"name": "Dev", "cgpa": 7.8}
]

result = sorted(students, key=lambda x: x["cgpa"], reverse=True)

print(result)
# Out:
# [{'name': 'Sanya', 'cgpa': 9.1}, {'name': 'Arjun', 'cgpa': 8.4}, {'name': 'Dev', 'cgpa': 7.8}]
