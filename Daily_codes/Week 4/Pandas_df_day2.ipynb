# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.shape
# Out:
# (10, 5)

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
df.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.head(7)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19

# %%
df.tail()
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.tail(6)
# Out:
#    roll    name class  marks  age
# 4     5    asha    TE  63.28   20
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.tail(3)
# Out:
#    roll   name class  marks  age
# 7     8  amita    BE  68.33   23
# 8     9   amol    TE  56.75   20
# 9    10  anmol    BE  78.66   21

# %%
df.values
# Out:
# array([[1, 'anil', 'TE', 56.77, 22],
#        [2, 'amit', 'TE', 59.77, 21],
#        [3, 'aniket', 'BE', 76.88, 19],
#        [4, 'ajinkya', 'TE', 69.66, 20],
#        [5, 'asha', 'TE', 63.28, 20],
#        [6, 'ayesha', 'BE', 49.55, 20],
#        [7, 'amar', 'BE', 65.34, 19],
#        [8, 'amita', 'BE', 68.33, 23],
#        [9, 'amol', 'TE', 56.75, 20],
#        [10, 'anmol', 'BE', 78.66, 21]], dtype=object)

# %%
"""
# slicing
   Index based -> loc
   column name -> iloc
""";

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[1:4,1:4]
# Out:
#       name class  marks
# 1     amit    TE  59.77
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66

# %%
df.iloc[1:5,[0,1,3]]
# Out:
#    roll     name  marks
# 1     2     amit  59.77
# 2     3   aniket  76.88
# 3     4  ajinkya  69.66
# 4     5     asha  63.28

# %%
df.iloc[[1,2,3,4,6],[0,1,3]]
# Out:
#    roll     name  marks
# 1     2     amit  59.77
# 2     3   aniket  76.88
# 3     4  ajinkya  69.66
# 4     5     asha  63.28
# 6     7     amar  65.34

# %%
df.replace('ayesha','geet')     # if ayesha is repeated many times this will not work
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6     geet    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[5,1] = 'geet'

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6     geet    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
# loc

# %%
df.loc[2:5,'name']
# Out:
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# Name: name, dtype: object

# %%
df.loc[2:5,['name','class']]
# Out:
#       name class
# 2   aniket    BE
# 3  ajinkya    TE
# 4     asha    TE
# 5     geet    BE

# %%
df.loc[0:10,'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.loc[:,'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df['name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df[['name','class']]
# Out:
#       name class
# 0     anil    TE
# 1     amit    TE
# 2   aniket    BE
# 3  ajinkya    TE
# 4     asha    TE
# 5     geet    BE
# 6     amar    BE
# 7    amita    BE
# 8     amol    TE
# 9    anmol    BE

# %%
# methods on coloumns/series

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6     geet    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df['name'].str.upper()                       # here we cannot directly use upper() becoz column is of object not string  so we use str
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5       GEET
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.lower()
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
#add or modify the coloumns

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6     geet    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
gender = ['m','f','m','m','f','f','f','m','f','m']

# %%
df['gender'] = gender

# %%
df
# Out:
#    roll     name class  marks  age gender
# 0     1     anil    TE  56.77   22      m
# 1     2     amit    TE  59.77   21      f
# 2     3   aniket    BE  76.88   19      m
# 3     4  ajinkya    TE  69.66   20      m
# 4     5     asha    TE  63.28   20      f
# 5     6     geet    BE  49.55   20      f
# 6     7     amar    BE  65.34   19      f
# 7     8    amita    BE  68.33   23      m
# 8     9     amol    TE  56.75   20      f
# 9    10    anmol    BE  78.66   21      m

# %%
df['roll'] = df['roll'] + 100

# %%
df
# Out:
#    roll     name class  marks  age gender
# 0   101     anil    TE  56.77   22      m
# 1   102     amit    TE  59.77   21      f
# 2   103   aniket    BE  76.88   19      m
# 3   104  ajinkya    TE  69.66   20      m
# 4   105     asha    TE  63.28   20      f
# 5   106     geet    BE  49.55   20      f
# 6   107     amar    BE  65.34   19      f
# 7   108    amita    BE  68.33   23      m
# 8   109     amol    TE  56.75   20      f
# 9   110    anmol    BE  78.66   21      m

# %%
# add a new column cgpa
# values should  => marks/10 +1.5

# %%
df['cgpa'] = df['marks']/10 + 1.5

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      f  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106     geet    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      f  8.034
# 7   108    amita    BE  68.33   23      m  8.333
# 8   109     amol    TE  56.75   20      f  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
df.sort_values(by = 'name')
# Out:
#    roll     name class  marks  age gender   cgpa
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 6   107     amar    BE  65.34   19      f  8.034
# 1   102     amit    TE  59.77   21      f  7.477
# 7   108    amita    BE  68.33   23      m  8.333
# 8   109     amol    TE  56.75   20      f  7.175
# 2   103   aniket    BE  76.88   19      m  9.188
# 0   101     anil    TE  56.77   22      m  7.177
# 9   110    anmol    BE  78.66   21      m  9.366
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106     geet    BE  49.55   20      f  6.455

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      f  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106     geet    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      f  8.034
# 7   108    amita    BE  68.33   23      m  8.333
# 8   109     amol    TE  56.75   20      f  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
# sort by class and then marks simultaneously and check the result

# %%
df.sort_values(by = ['name','marks'])
# Out:
#    roll     name class  marks  age gender   cgpa
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 6   107     amar    BE  65.34   19      f  8.034
# 1   102     amit    TE  59.77   21      f  7.477
# 7   108    amita    BE  68.33   23      m  8.333
# 8   109     amol    TE  56.75   20      f  7.175
# 2   103   aniket    BE  76.88   19      m  9.188
# 0   101     anil    TE  56.77   22      m  7.177
# 9   110    anmol    BE  78.66   21      m  9.366
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106     geet    BE  49.55   20      f  6.455

# %%
df['marks'].mean()
# Out:
# np.float64(64.499)

# %%
df['marks'].max()
# Out:
# 78.66

# %%
df.describe()
# Out:
#             roll      marks        age       cgpa
# count   10.00000  10.000000  10.000000  10.000000
# mean   105.50000  64.499000  20.500000   7.949900
# std      3.02765   9.207179   1.269296   0.920718
# min    101.00000  49.550000  19.000000   6.455000
# 25%    103.25000  57.520000  20.000000   7.252000
# 50%    105.50000  64.310000  20.000000   7.931000
# 75%    107.75000  69.327500  21.000000   8.432750
# max    110.00000  78.660000  23.000000   9.366000

# %%
# groupby

# %%
gr = df.groupby('class')

# %%
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
gr.get_group('BE')
# Out:
#    roll    name class  marks  age gender   cgpa
# 2   103  aniket    BE  76.88   19      m  9.188
# 5   106    geet    BE  49.55   20      f  6.455
# 6   107    amar    BE  65.34   19      f  8.034
# 7   108   amita    BE  68.33   23      m  8.333
# 9   110   anmol    BE  78.66   21      m  9.366

# %%
gr.get_group('TE')
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      f  7.477
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 8   109     amol    TE  56.75   20      f  7.175

# %%
gr.min()
# Out:
#        roll     name  marks  age gender   cgpa
# class
# BE      103     amar  49.55   19      f  6.455
# TE      101  ajinkya  56.75   20      f  7.175

# %%
gr['marks'].mean()
# Out:
# class
# BE    67.752
# TE    61.246
# Name: marks, dtype: float64

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      f  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106     geet    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      f  8.034
# 7   108    amita    BE  68.33   23      m  8.333
# 8   109     amol    TE  56.75   20      f  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
df['marks']>60
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
df[df['marks']>60]
# Out:
#    roll     name class  marks  age gender   cgpa
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 6   107     amar    BE  65.34   19      f  8.034
# 7   108    amita    BE  68.33   23      m  8.333
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
# filter the data of those students -> marks -> 60 and belong to be class

# %%
df[(df['class']=='BE') &(df['marks']>60)]
# Out:
#    roll    name class  marks  age gender   cgpa
# 2   103  aniket    BE  76.88   19      m  9.188
# 6   107    amar    BE  65.34   19      f  8.034
# 7   108   amita    BE  68.33   23      m  8.333
# 9   110   anmol    BE  78.66   21      m  9.366

# %%
df.drop(4)
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      f  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 5   106     geet    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      f  8.034
# 7   108    amita    BE  68.33   23      m  8.333
# 8   109     amol    TE  56.75   20      f  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
df.drop([4,5,6])
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      f  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 7   108    amita    BE  68.33   23      m  8.333
# 8   109     amol    TE  56.75   20      f  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
# drop column name

# %%
df.drop(columns ='name')
# Out:
#    roll class  marks  age gender   cgpa
# 0   101    TE  56.77   22      m  7.177
# 1   102    TE  59.77   21      f  7.477
# 2   103    BE  76.88   19      m  9.188
# 3   104    TE  69.66   20      m  8.466
# 4   105    TE  63.28   20      f  7.828
# 5   106    BE  49.55   20      f  6.455
# 6   107    BE  65.34   19      f  8.034
# 7   108    BE  68.33   23      m  8.333
# 8   109    TE  56.75   20      f  7.175
# 9   110    BE  78.66   21      m  9.366

# %%
df.drop('name',axis = 1)            #work rowwise so we have to provide axis
# Out:
#    roll class  marks  age gender   cgpa
# 0   101    TE  56.77   22      m  7.177
# 1   102    TE  59.77   21      f  7.477
# 2   103    BE  76.88   19      m  9.188
# 3   104    TE  69.66   20      m  8.466
# 4   105    TE  63.28   20      f  7.828
# 5   106    BE  49.55   20      f  6.455
# 6   107    BE  65.34   19      f  8.034
# 7   108    BE  68.33   23      m  8.333
# 8   109    TE  56.75   20      f  7.175
# 9   110    BE  78.66   21      m  9.366

# %%
# drop name and class

# %%
df.drop(['name','class'],axis = 1)
# Out:
#    roll  marks  age gender   cgpa
# 0   101  56.77   22      m  7.177
# 1   102  59.77   21      f  7.477
# 2   103  76.88   19      m  9.188
# 3   104  69.66   20      m  8.466
# 4   105  63.28   20      f  7.828
# 5   106  49.55   20      f  6.455
# 6   107  65.34   19      f  8.034
# 7   108  68.33   23      m  8.333
# 8   109  56.75   20      f  7.175
# 9   110  78.66   21      m  9.366

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      f  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106     geet    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      f  8.034
# 7   108    amita    BE  68.33   23      m  8.333
# 8   109     amol    TE  56.75   20      f  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
df.drop(['gender', 'cgpa'], axis = 1, inplace = True)
         #Reflect in actual dataset (use of inplace)

# %%
df
# Out:
#    roll     name class  marks  age
# 0   101     anil    TE  56.77   22
# 1   102     amit    TE  59.77   21
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 5   106     geet    BE  49.55   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 8   109     amol    TE  56.75   20
# 9   110    anmol    BE  78.66   21

# %%
df
#create a dataframe newdf
#coloumns -> row ,gender ,cgpa
# roll column will have the same values as the df dataframe
# Out:
#    roll     name class  marks  age
# 0   101     anil    TE  56.77   22
# 1   102     amit    TE  59.77   21
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 5   106     geet    BE  49.55   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 8   109     amol    TE  56.75   20
# 9   110    anmol    BE  78.66   21

# %%
newdf = pd.DataFrame({
    'roll':df['roll'],
    'genger':gender,
    'cgpa':df['marks']/10 + 1.5
})
newdf
# Out:
#    roll genger   cgpa
# 0   101      m  7.177
# 1   102      f  7.477
# 2   103      m  9.188
# 3   104      m  8.466
# 4   105      f  7.828
# 5   106      f  6.455
# 6   107      f  8.034
# 7   108      m  8.333
# 8   109      f  7.175
# 9   110      m  9.366

# %%
pd.merge(df,newdf)
# Out:
#    roll     name class  marks  age genger   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      f  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106     geet    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      f  8.034
# 7   108    amita    BE  68.33   23      m  8.333
# 8   109     amol    TE  56.75   20      f  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
# concat

# %%
# load  student5.csv

# %%
da = pd.read_csv('student5.csv')

# %%
da
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
pd.concat([df,da])              # but has index problem
# Out:
#    roll     name class  marks  age
# 0   101     anil    TE  56.77   22
# 1   102     amit    TE  59.77   21
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 5   106     geet    BE  49.55   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 8   109     amol    TE  56.75   20
# 9   110    anmol    BE  78.66   21
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
pd.concat([df,da] , ignore_index = True)          # improvrd version
# Out:
#     roll     name class  marks  age
# 0    101     anil    TE  56.77   22
# 1    102     amit    TE  59.77   21
# 2    103   aniket    BE  76.88   19
# 3    104  ajinkya    TE  69.66   20
# 4    105     asha    TE  63.28   20
# 5    106     geet    BE  49.55   20
# 6    107     amar    BE  65.34   19
# 7    108    amita    BE  68.33   23
# 8    109     amol    TE  56.75   20
# 9    110    anmol    BE  78.66   21
# 10     1   surbhi    TE  67.44   23
# 11     2    sujay    TE  74.12   22
# 12     3  subhash    BE  82.44   21
# 13     4   sachin    TE  59.33   21
# 14     5  shalini    TE  63.45   20

# %%
f = df[(df['class']=='BE') &(df['marks']>60)]

# %%
f.to_csv('op.csv', index = False)
