# %%
"""
create a sample text file with some text in it
""";

# %%
# open the file

f = open("sample.txt")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='r' encoding='cp1252'>

# %%
f.readable()
# Out:
# True

# %%
f.readline()
# Out:
# 'hi ,hello. This is vaishnavi.An Second year polytechnic student.'

# %%
f.readline()
# Out:
# ''

# %%
f = open("sample.txt")

# %%
f.readline(10)
# Out:
# 'hi ,hello.'

# %%
f.readline(5)
# Out:
# ' This'

# %%
# check readlines

# %%
f = open("sample.txt")

# %%
f.readlines()
# Out:
# ['hi ,hello. This is vaishnavi.An Second year polytechnic student.']

# %%
f = open("sample.txt")

# %%
data = f.readlines()

# %%
for line in data:
    print(line)
# Out:
# hi ,hello. This is vaishnavi.An Second year polytechnic student.

# %%
# convert the data in uppercase

# %%
for line in data:
    print(line.upper())
# Out:
# HI ,HELLO. THIS IS VAISHNAVI.AN SECOND YEAR POLYTECHNIC STUDENT.

# %%
f = open("sample.txt")

# %%
f.read()     # read the data from file and return it as a string
# Out:
# 'hi ,hello. This is vaishnavi.An Second year polytechnic student.'

# %%
f = open("sample.txt")

# %%
text = f.read()

# %%
text.split()
# Out:
# ['hi',
#  ',hello.',
#  'This',
#  'is',
#  'vaishnavi.An',
#  'Second',
#  'year',
#  'polytechnic',
#  'student.']

# %%
s = open("sample1.txt", "r", encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 s = open("sample1.txt", "r", encoding="utf-8")
#
# File D:\anaconda\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample1.txt'
