# %% [markdown]
# # Data structures

# %%
l = [21,45,66,4,76,64]

# %%
l
# Out:
# [21, 45, 66, 4, 76, 64]

# %%
print(l)
# Out:
# [21, 45, 66, 4, 76, 64]

# %%
l1 = [ 86,35,65,86,"java","python",52.97]

# %%
l1
# Out:
# [86, 35, 65, 86, 'java', 'python', 52.97]

# %%
l1[2]
# Out:
# 65

# %%
# list are heteregeneous and allow duplicates

# %%
l1[1] = 100

# %%
l1
# Out:
# [86, 100, 65, 86, 'java', 'python', 52.97]

# %%
l1[4] = True

# %%
l1
# Out:
# [86, 100, 65, 86, True, 'python', 52.97]

# %% [markdown]
# # list slicing

# %%
l = [12,34,65,35,63,67]

# %%
l
# Out:
# [12, 34, 65, 35, 63, 67]

# %%
l[1:4]
# Out:
# [34, 65, 35]

# %%
l[0:6:2]
# Out:
# [12, 65, 63]

# %%
l[::2]
# Out:
# [12, 65, 63]

# %%
l1.reverse()

# %%
l1
# Out:
# [52.97, 'python', True, 86, 65, 100, 86]

# %%
l.reverse()

# %%
l
# Out:
# [67, 63, 35, 65, 34, 12]

# %%
l[::-1]
# Out:
# [12, 34, 65, 35, 63, 67]

# %%
l
# Out:
# [67, 63, 35, 65, 34, 12]

# %%
l[1:4]=[100,200,300]

# %%
l
# Out:
# [67, 100, 200, 300, 34, 12]

# %%
l1 = [12,24,56,23]

# %%
del l1[-2]

# %%
l1
# Out:
# [12, 24, 23]

# %%
del l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 del l1
#
# NameError: name 'l1' is not defined

# %% [markdown]
# # membership operator

# %%
l
# Out:
# [67, 100, 200, 300, 34, 12]

# %%
89 in l
# Out:
# False

# %%
67 in l
# Out:
# True

# %% [markdown]
# # arithmetic operators

# %%
l * 2    # repetation of list
# Out:
# [67, 100, 200, 300, 34, 12, 67, 100, 200, 300, 34, 12]

# %%
l + [60 , 70,80]   # conctination of list
# Out:
# [67, 100, 200, 300, 34, 12, 60, 70, 80]

# %%
l1 = [43,54,54,45]

# %%
l + l1
# Out:
# [67, 100, 200, 300, 34, 12, 43, 54, 54, 45]

# %%
for i in l:
    print(i**2,end = " ")
# Out:
# 4489 10000 40000 90000 1156 144

# %%
for i in l:
    if(i%2!=0):
        print(i)
# Out:
# 67

# %%
l
# Out:
# [67, 100, 200, 300, 34, 12]

# %% [markdown]
# # list comprehension

# %%
new1 = [ i**2 for i in l]

# %%
new1
# Out:
# [4489, 10000, 40000, 90000, 1156, 144]

# %%
newl2 = [ i for i in l if i % 2 == 1]

# %%
newl2
# Out:
# [67]

# %%
name = ["aryan","Aryan","samruddhi","swaraj","Sukanya","shivraj"]

# %%
name
# Out:
# ['aryan', 'Aryan', 'samruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
new_list = [name for name in name if name.startswith(("S", "s"))]

print(new_list)
# Out:
# ['samruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
# functions

# %%
l
# Out:
# [67, 100, 200, 300, 34, 12]

# %%
len(l)
# Out:
# 6

# %%
max(l)
# Out:
# 300

# %%
min(l)
# Out:
# 12

# %%
sorted(l)
# Out:
# [12, 34, 67, 100, 200, 300]

# %%
sorted(l, reverse = True)
# Out:
# [300, 200, 100, 67, 34, 12]

# %%
# list methods

# %%
l
# Out:
# [67, 100, 200, 300, 34, 12]

# %%
l.append(100)

# %%
l
# Out:
# [67, 100, 200, 300, 34, 12, 100]

# %%
l1 = [1,2,3]
l2 = [1,2,3]

# %%
l1.append([100,200])
l2.extend([100,200])

# %%
l1
# Out:
# [1, 2, 3, [100, 200]]

# %%
l2
# Out:
# [1, 2, 3, 100, 200]

# %%
l1[3][1]
# Out:
# 200

# %%
l1[3][1] = 476

# %%
l1
# Out:
# [1, 2, 3, [100, 476]]

# %%
l.insert(1,78)

# %%
l
# Out:
# [67, 78, 100, 200, 300, 34, 12, 100]

# %%
l.remove(78)

# %%
l
# Out:
# [67, 100, 200, 300, 34, 12, 100]

# %%
l.pop()
# Out:
# 100

# %%
l.pop(3)
# Out:
# 300

# %%
l.index(67)
# Out:
# 0

# %%
l.index(67)
# Out:
# 0

# %%
l.sort()

# %%
l
# Out:
# [12, 34, 67, 100, 200]

# %%
l.sort(reverse = True)

# %%
l
# Out:
# [200, 100, 67, 34, 12]

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']
